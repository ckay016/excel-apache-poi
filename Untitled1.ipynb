# %% [markdown]
# <a href="https://colab.research.google.com/github/ckay016/excel-apache-poi/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cd collab

# %%
# !unzip hey.zip -d collab
# Out:
# unzip:  cannot find or open hey.zip, hey.zip.zip or hey.zip.ZIP.

# %%
# !unzip Xception-with-Your-Own-Dataset-master.rar -d collab/
# Out:
# Archive:  Xception-with-Your-Own-Dataset-master.rar
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of Xception-with-Your-Own-Dataset-master.rar or
#         Xception-with-Your-Own-Dataset-master.rar.zip, and cannot find Xception-with-Your-Own-Dataset-master.rar.ZIP, period.

# %%
# !unzip xceptionmodel.zip -d collab/
# Out:
# Archive:  xceptionmodel.zip
#    creating: collab/xceptionmodel/
#   inflating: collab/xceptionmodel/.gitignore
#   inflating: collab/xceptionmodel/classes.txt
#    creating: collab/xceptionmodel/dataset/
#    creating: collab/xceptionmodel/dataset/Accident/
#   inflating: collab/xceptionmodel/dataset/Accident/035836ea0039e8f147b6a3785e818fb3--car-insurance-st-louis.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/0630-venus-williams-car-crash-2.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/0819182143b_resize-300x169.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/0_aftermath-of-crash-on-A180.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/1200px-Car_accident_poland_2008.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/138360.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/140214123410-pennsylvania-turnpike-crash-horizontal-large-gallery.jpg
#   inflating: collab/xceptionmodel/dataset/Accident/1464499615619.jpg
# ...

# %%
# !cd collab/Xception-with-Your-Own-Dataset-master

# %%
# !python fine_tune.py 101_ObjectCategories/ classes.txt result/

# %%
# !python inference.py result/model_fine_final.h5 classes.txt images/crayfish.jpg

# %%
import os
os.chdir('collab/xceptionmodel')

# %%
# !python fine_tune.py 101_ObjectCategories/ classes.txt result/ --epochs_pre 2 --epochs_fine 10 --lr_pre 5e-3 --lr_fine 5e-4

# %%
# !cd /

# %%
# !ls
# Out:
# 101_ObjectCategories  result

# %%
# !rm -rf Xception-with-Your-Own-Dataset-master

# %%
# %cd collab
# Out:
# /content/collab

# %%
# !pwd
# Out:
# /content/collab/collab/xceptionmodel

# %%
# !ls
# Out:
# collab	xceptionmodel.zip

# %%
# !python fine_tune.py dataset/ labels.txt result/
# Out:
# Using TensorFlow backend.
# Training on 546 images and labels
# Validation on 137 images and labels
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
# !python inference.py result/model_fine_final.h5 labels.txt images/a57bddc8-e908-4b94-9e75-8a6be09b62a9.jpg
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...
